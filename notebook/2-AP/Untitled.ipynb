# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
phi = arange(-180,180,0.01)

# %%
u = 12*(phi/70)**2
v = -minimum(v,20)

# %%
polar(phi*pi/180,v+14)
